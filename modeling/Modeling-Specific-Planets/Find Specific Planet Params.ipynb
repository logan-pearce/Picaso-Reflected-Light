# %%
pl = pd.read_csv('../../ExploringGmagAOXTargetList/GMagAO-X-target-list.csv')
ind = [i for i in range(len(pl)) if '3021' in pl['pl_name'].loc[i]]
gj = pl.loc[ind]
gj
# Out:
#     loc_rowid    pl_name hostname  hd_name  hip_name  \
# 47        530  GJ 3021 b  GJ 3021  HD 1237  HIP 1292
#
#                          gaia_id  default_flag  sy_snum  sy_pnum  \
# 47  Gaia DR2 4634528720388462592             1        2        1
#
#     discoverymethod  ...  Mam Inferred Teff from SpT Sep arcsec   Sep lod  \
# 47  Radial Velocity  ...                         NaN   0.027911  4.295537
#
#            Re  SpT  StarTeff  Mam Inferred StarRad from Teff  StarRad  \
# 47  11.944287  4.6    5540.0                             NaN      0.9
#
#            Teq  Giant
# 47  331.162221  False
#
# [1 rows x 159 columns]

# %%
[print(c, gj[c].item()) for c in gj.columns]
# Out:
# loc_rowid 530
# pl_name GJ 3021 b
# hostname GJ 3021
# hd_name HD 1237
# hip_name HIP 1292
# gaia_id Gaia DR2 4634528720388462592
# default_flag 1
# sy_snum 2
# sy_pnum 1
# discoverymethod Radial Velocity
# disc_year 2000
# soltype Published Confirmed
# pl_controv_flag 0
# pl_refname <a refstr=NAEF_ET_AL__2001 href=https://ui.adsabs.harvard.edu/abs/2001A&A...375..205N/abstract target=ref> Naef et al. 2001 </a>
# pl_orbper 133.71
# pl_orbpererr1 0.2
# pl_orbpererr2 -0.2
# pl_orbperlim 0.0
# pl_orbsmax 0.49
# pl_orbsmaxerr1 nan
# pl_orbsmaxerr2 nan
# pl_orbsmaxlim 0.0
# pl_rade nan
# pl_radeerr1 nan
# pl_radeerr2 nan
# pl_radelim nan
# pl_radj nan
# pl_radjerr1 nan
# pl_radjerr2 nan
# pl_radjlim nan
# pl_masse nan
# pl_masseerr1 nan
# pl_masseerr2 nan
# pl_masselim nan
# pl_massj nan
# pl_massjerr1 nan
# pl_massjerr2 nan
# pl_massjlim nan
# pl_msinie 1071.04
# pl_msinieerr1 28.6
# pl_msinieerr2 -28.6
# pl_msinielim 0.0
# pl_msinij 3.37
# pl_msinijerr1 0.09
# pl_msinijerr2 -0.09
# pl_msinijlim 0.0
# pl_bmasse 1071.04
# pl_bmasseerr1 28.6
# pl_bmasseerr2 -28.6
# pl_bmasselim 0.0
# pl_bmassj 3.37
# pl_bmassjerr1 0.09
# pl_bmassjerr2 -0.09
# pl_bmassjlim 0.0
# pl_bmassprov Msini
# pl_orbeccen 0.511
# pl_orbeccenerr1 0.017
# pl_orbeccenerr2 -0.017
# pl_orbeccenlim 0.0
# pl_insol nan
# pl_insolerr1 nan
# pl_insolerr2 nan
# pl_insollim nan
# pl_eqt 350.0
# pl_eqterr1 90.0
# pl_eqterr2 -90.0
# pl_eqtlim 0.0
# pl_orbincl nan
# pl_orbinclerr1 nan
# pl_orbinclerr2 nan
# pl_orbincllim nan
# ttv_flag 0.0
# pl_orbtper 2451545.86
# pl_orbtpererr1 0.64
# pl_orbtpererr2 -0.64
# pl_orbtperlim 0.0
# pl_orblper 290.7
# pl_orblpererr1 3.0
# pl_orblpererr2 -3.0
# pl_orblperlim 0.0
# st_refname <a refstr=NAEF_ET_AL__2001 href=https://ui.adsabs.harvard.edu/abs/2001A&A...375..205N/abstract target=ref> Naef et al. 2001 </a>
# st_spectype G6 V
# st_teff 5540.0
# st_tefferr1 75.0
# st_tefferr2 -75.0
# st_tefflim 0.0
# st_rad 0.9
# st_raderr1 nan
# st_raderr2 nan
# st_radlim 0.0
# st_mass 0.9
# st_masserr1 nan
# st_masserr2 nan
# st_masslim 0.0
# st_met 0.1
# st_meterr1 0.08
# st_meterr2 -0.08
# st_metlim 0.0
# st_metratio [Fe/H]
# st_logg 4.7
# st_loggerr1 0.2
# st_loggerr2 -0.2
# st_logglim 0.0
# sy_refname <a refstr=STASSUN_ET_AL__2019 href=https://ui.adsabs.harvard.edu/abs/2019AJ....158..138S/abstract target=ref>TICv8</a>
# rastr 00h16m15.22s
# ra 4.0634323
# decstr -79d51m05.12s
# dec -79.8514218
# sy_dist 17.5559
# sy_disterr1 0.0073
# sy_disterr2 -0.0073
# sy_plx 56.9319
# sy_plxerr1 0.0234909
# sy_plxerr2 -0.0234909
# sy_jmag 5.366
# sy_jmagerr1 0.021
# sy_jmagerr2 -0.021
# sy_hmag 4.99
# sy_hmagerr1 0.038
# sy_hmagerr2 -0.038
# sy_kmag 4.859
# sy_kmagerr1 0.023
# sy_kmagerr2 -0.023
# sy_umag nan
# sy_umagerr1 nan
# sy_umagerr2 nan
# sy_gmag nan
# sy_gmagerr1 nan
# sy_gmagerr2 nan
# sy_rmag nan
# sy_rmagerr1 nan
# sy_rmagerr2 nan
# sy_imag nan
# sy_imagerr1 nan
# sy_imagerr2 nan
# sy_zmag nan
# sy_zmagerr1 nan
# sy_zmagerr2 nan
# sy_gaiamag 6.39729
# sy_gaiamagerr1 0.0008267
# sy_gaiamagerr2 -0.0008267
# rowupdate 2014-05-14
# pl_pubdate 2001-08
# releasedate 2014-05-14
# M2R infered radius [Rearth] 11.94428742428012
# Flux Contrast alpha=0 Ag=0.5 3.600301741540871e-07
# Flux Contrast alpha=90 Ag=0.5 1.1460116375771781e-07
# SpT Number 4.6
# Mam Inferred SpT from Teff nan
# Mam Inferred Teff from SpT nan
# Sep arcsec 0.0279108447872225
# Sep lod 4.295537188532792
# Re 11.94428742428012
# SpT 4.6
# StarTeff 5540.0
# Mam Inferred StarRad from Teff nan
# StarRad 0.9
# Teq 331.162221499752
# Giant False
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# Out:
# 'GJ 3021 b'
