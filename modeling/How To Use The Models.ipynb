# %%
savefiledirectory = 'ReflectXGasGiantModelGrid-Neptune-Tstar3000-Rstar0.2-Teq187-sep0.1-rad0.35-mass0.05-mh100-co0.5-phase0'
specdict = pickle.load(
    open(savefiledirectory+'/cloud-free-spectrum-full-output-R150.pkl','rb'))

# %% [markdown]
# # Human and Machine readable model spectrum files

# %%
s = pd.read_csv(savefiledirectory+'/cloud-free-spectrum-R150.csv', delim_whitespace=True)
s
# Out:
#      wavelength [um]  planet flux [ergs/cm2/s/cm]  star flux [ergs/cm2/s/cm]  \
# 0           2.001223                 2.862777e+02               1.223023e+13
# 1           1.987926                 1.719802e+02               1.114631e+13
# 2           1.974717                 1.500685e+02               1.299343e+13
# 3           1.961596                 1.646002e+02               1.333335e+13
# 4           1.948562                 1.354363e+02               1.227296e+13
# ..               ...                          ...                        ...
# 237         0.412200                 3.008568e+06               1.749541e+12
# 238         0.409461                 3.379882e+06               1.868205e+12
# 239         0.406740                 2.828290e+06               1.625202e+12
# 240         0.404038                 2.219757e+06               1.325115e+12
# 241         0.401353                 2.789724e+06               1.788699e+12
#
#        albedo  planet-star contrast
# 0    0.000008          2.340739e-11
# 1    0.000006          1.542934e-11
# 2    0.000004          1.154957e-11
# 3    0.000004          1.234500e-11
# 4    0.000004          1.103534e-11
# ..        ...                   ...
# 237  0.614661          1.719632e-06
# 238  0.646661          1.809160e-06
# 239  0.622038          1.740270e-06
# 240  0.598759          1.675144e-06
# 241  0.557473          1.559639e-06
#
# [242 rows x 5 columns]

# %%
# %matplotlib notebook
plt.plot(s['wavelength [um]'],s['planet flux [ergs/cm2/s/cm]'])
plt.gca().set_yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="800">
