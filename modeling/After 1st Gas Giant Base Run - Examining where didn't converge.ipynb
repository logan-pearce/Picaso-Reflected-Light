# %%
failedtoconverge = pd.read_csv('After-Initial-GasGiantBaseRun-FailedToConverge.csv')

for i in range(len(failedtoconverge)):
    print(failedtoconverge['dir'][i].split('-')[1:])
# Out:
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase45']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase140']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase0']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase120']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase0']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.54', 'mass0.09', 'mh50', 'co1.5', 'phase0']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase45']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase140']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq84', 'sep0.5', 'rad0.54', 'mass0.09', 'mh50', 'co1.5', 'phase90']
# ...

# %%
def MakePTProflePlot(atm_df,title):
    #### Plot PT profile:
    fig = plt.figure(figsize=(10,10))
    plt.ylabel("Pressure [Bars]", fontsize=25)
    plt.xlabel('Temperature [K]', fontsize=25)
    plt.ylim(500,1e-6)
    #plt.xlim(0,3000)
    plt.semilogy(atm_df['temperature'],
                atm_df['pressure'],color="r",linewidth=3)
    plt.minorticks_on() 
    plt.tick_params(axis='both',which='major',length =30, width=2,direction='in',labelsize=23)
    plt.tick_params(axis='both',which='minor',length =10, width=2,direction='in',labelsize=23)
    #plt.legend(fontsize=15)
    plt.title(title, fontsize = 15)

    return fig

# %%
failedtoconverge['dir'][0].split('/')[-1]
# Out:
# 'ReflectXGasGiantModelGrid-Neptune-Tstar3000-Rstar0.2-Teq84-sep0.5-rad0.35-mass0.05-mh100-co1.5-phase45'

# %%
# Out:
# 'SuperNepTstar3000Rstar0.2Teq84sep0.5rad0.54mass0.09mh50co0.5phase0'

# %%
os.system('mkdir FailedToConvergePTPlots')
plt.ioff()
for i in range(len(failedtoconverge)):
    file = '/Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/'+failedtoconverge['dir'][i].split('/')[-1]+'/cloud-free-model.pkl'
    pl = pickle.load(open(file,'rb'))[1]
    title = 'i = '+str(i)+', \n'+(''.join(failedtoconverge['dir'][i].split('/')[-1].split('-')[1:]))
    fig = MakePTProflePlot(pl, title)
    fig.savefig('FailedToConvergePTPlots/'+failedtoconverge['dir'][i].split('/')[-1]+'.png')
plt.ion()
# Out:
# mkdir: FailedToConvergePTPlots: File exists

# %%
os.system('say "Done"')
# Out:
# 0

# %%
file = '/Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/'+failedtoconverge['dir'][0].split('/')[-1]+'/cloud-free-model.pkl'
pl = pickle.load(open(file,'rb'))[1]
fig = MakePTProflePlot(pl)
# %matplotlib notebook

# plt.plot(pl['temperature'],pl['pressure'])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
onesthatlookbad = [73,74,45,46,47,48,49]
failedtoconverge.loc[onesthatlookbad]
# Out:
#                                                   dir                date  \
# 73  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-3:38:55
# 74  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-3:44:49
# 45  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-29-20:52:42
# 46  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-29-20:58:33
# 47  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-29-20:59:55
# 48  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-29-21:1:13
# 49  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-29-21:3:39
#
#     result                  note
# 73  FAILED   failed to converge
# 74  FAILED   failed to converge
# 45  FAILED   failed to converge
# 46  FAILED   failed to converge
# 47  FAILED   failed to converge
# 48  FAILED   failed to converge
# 49  FAILED   failed to converge

# %%
i = 73
file = '/Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/'+failedtoconverge['dir'][i].split('/')[-1]+'/cloud-free-model.pkl'
pl = pickle.load(open(file,'rb'))[1]
title = 'i = '+str(i)+', \n'+(''.join(failedtoconverge['dir'][i].split('/')[-1].split('-')[1:]))
fig = MakePTProflePlot(pl,title)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
i = 73
file = '/Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/ReflectXGasGiantModelGrid-SuperJup-Tstar7000-Rstar10.0-Teq3087-sep0.1-rad0.9-mass5.0-mh1-co1.5-phase0/cloud-free-model.pkl'
pl = pickle.load(open(file,'rb'))[1]
#title = 'i = '+str(i)+', \n'+(''.join(failedtoconverge['dir'][i].split('/')[-1].split('-')[1:]))
fig = MakePTProflePlot(pl,'ReflectXGasGiantModelGrid-SuperJup-Tstar7000-Rstar10.0-Teq3087-sep0.1-rad0.9-mass5.0-mh1-co1.5-phase0')
plt.savefig('ReflectXGasGiantModelGrid-SuperJup-Tstar7000-Rstar10.0-Teq3087-sep0.1-rad0.9-mass5.0-mh1-co1.5-phase0.png')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
import pysynphot as S
bb = S.BlackBody(7000)
# %matplotlib notebook
plt.plot(bb.wave*u.AA.to(u.um),bb.flux)
plt.axvline(x=0.3,ls=':')
plt.xlabel('um')
plt.ylabel(bb.fluxunits)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#d = pd.read_table('ReflectXGasGiantRunReport.txt', delim_whitespace = True, names=['dir','result','notes'])
with open('ReflectXGasGiantRunReport-after-1st-base-run.txt','r') as f:
    d = f.read().splitlines()
    

direct = []
date = []
result = []
note = []
d[0].split(' ')
for i in range(len(d)):
    dd = d[i].split(' ')
    direct.append(dd[0])
    date.append(dd[1])
    result.append(dd[3])
    note.append(' '.join(dd[4:]))
    
df = pd.DataFrame({'dir':direct, 'date':date, 'result':result, 'note':note})
df
# Out:
#                                                     dir                date  \
# 0     /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-28-20:25:41
# 1     /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-28-20:25:40
# 2     /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-28-20:25:41
# 3     /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-28-20:25:41
# 4     /data2/lpearce/ReflectXGasGiantModelGrid/Refle...  2023-6-28-20:25:41
# ...                                                 ...                 ...
# 1253  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-6:55:28
# 1254  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-6:56:46
# 1255  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-6:56:53
# 1256  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...   2023-6-30-6:57:17
# 1257  /data2/lpearce/ReflectXGasGiantModelGrid/Refle...    2023-6-30-6:58:0
#
#          result               note
# ...

# %%
os.system('mkdir AllGiantStarPTProfiles')
plt.ioff()

for i in range(len(df)):
    if 'Rstar10' in df['dir'][i]:
        try:
            file = '/Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/'+df['dir'][i].split('/')[-1]+'/cloud-free-model.pkl'
            pl = pickle.load(open(file,'rb'))[1]
            #title = 'i = '+str(i)+', \n'+(''.join(df['dir'][i].split('/')[-1].split('-')[1:]))
            title = ''.join(df['dir'][i].split('/')[-1].split('-')[1:])
            fig = MakePTProflePlot(pl, title)
            fig.savefig('AllGiantStarPTProfiles/'+df['dir'][i].split('/')[-1]+'.png')
            plt.close()
        except:
            pass
plt.ion()
# Out:
# mkdir: AllGiantStarPTProfiles: File exists

# %%
os.system('say "Done"')
# Out:
# 0

# %%
os.system('ls AllGiantStarPTProfiles/* > list')
with open('list','r') as f:
    z = f.read().splitlines()

# %%
os.system('ls -d /Volumes/Oy/ReflectX/ReflectXGasGiantModelGrid/ReflectXGasGiantModelGrid-* > list2')
with open('list2','r') as f:
    z2 = f.read().splitlines()

# %%
for j in range(len(z)):
    for i in range(len(z2)):
        if z[j].split('/')[1].replace('.png','') in z2[i]:
            #print(i, z[j].split('/')[1].replace('.png',''), z2[i])
            os.system('mv '+z[j]+' '+z2[i]+'/cloud-free-PTprofile.png')

# %%
os.system('ls -d /Volumes/Oy/ReflectX/GasGiantRemovedFromGridDueToConvergenceIssue/ReflectXGasGiantModelGrid-* > list3')
with open('list3','r') as f:
    z3 = f.read().splitlines()

for j in range(len(z)):
    for i in range(len(z3)):
        if z[j].split('/')[1].replace('.png','') in z3[i]:
            #print(i, z[j].split('/')[1].replace('.png',''), z2[i])
            os.system('mv '+z[j]+' '+z3[i]+'/cloud-free-PTprofile.png')
