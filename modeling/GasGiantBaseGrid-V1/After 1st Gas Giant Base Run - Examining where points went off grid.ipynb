# %%
pointsoffgrid = pd.read_csv('After-Initial-GasGiantBaseRun-PointsOffGrid.csv')

for i in range(len(pointsoffgrid)):
    print(pointsoffgrid['dir'][i].split('-')[1:])
# Out:
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase0']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase45']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase120']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase90']
# ['Neptune', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.35', 'mass0.05', 'mh100', 'co1.5', 'phase140']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase0']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase45']
# ['SuperNep', 'Tstar3000', 'Rstar0.2', 'Teq19', 'sep10.0', 'rad0.54', 'mass0.09', 'mh50', 'co0.5', 'phase120']
# ...
