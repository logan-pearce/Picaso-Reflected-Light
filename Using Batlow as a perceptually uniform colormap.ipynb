# %%
from cmcrameri import cm
x = np.linspace(0,100,100)[None,:]
# %matplotlib notebook
plt.imshow(x, aspect='auto', cmap=cm.batlow)
# Out:
# <img src="data:image/png;base64,..." width="800.0000211927631">
